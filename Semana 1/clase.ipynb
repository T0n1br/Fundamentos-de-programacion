# %% [markdown]
# #Variables
#
# Las variables en Python son tipos de datos que tienen diferente forma
#
#     - Numericas
#         --Enteros
#         --Flotante
#     -Cadenas de caracteres
#     -Boleanos
#     -Compuestos

# %% [markdown]
# En este punto iniciamos el proceso de git y github

# %%
nombre = "Ricardo"
edad = 18
es_estudiante = True
esta_activo = None

print(type(nombre))
print(type(edad))
print(type(es_estudiante))
print(type(esta_activo))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'bool'>
# <class 'NoneType'>

# %%
nombre = "RICARDO"
edad =45

print("Hola", nombre, "tienes", edad, "años")
# Out:
# Hola RICARDO tienes 45 años

# %% [markdown]
# En este punto iniciamos el proyeto en git y github
#
# git -m comit "hasghdgha"
# git comit -m
#
# git -u push origin main
