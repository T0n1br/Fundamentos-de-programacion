# %% [markdown]
# # Cobro de entradas del museo
#
# Lo primero que hice fue hacer un diagrama de flujo externo, porque no podia resolverlo, despues empeze por el while para mientras sea verdadero para formar mi ciclo de visitantes o si escriben salir que terminara el programa, pedi con input la edad y declare la variable de lo que ingresan como entrada, por si tambien escribian salir, declare un if de si la entrada era igual a salir que rompiera el programa y imprimia fin del programa sino que edad porque en el input pedia la edad, era igual a float entrada por los numeros para cambiar la variable a numeros y a que esos valgan la edad, despues volvi a declarar con if que si la edad era igual o menos a 3 imprimiera que su entrada era gratis, o si es mayor a 3 y menor o igual a 17 su costo en variable es 30 y que imprimiera que su costo es de 30, sino ps ya son todos los demas numeros arriba de 18 y costo ahi es 45 y igual lo imprimiera despues termine esa conexion declare una variable afuera de visitante para saber el tipo y poner el descuento si decia que era adulto mayor puse un if visitante igual a adulto mayor, era el total * .88 porque si el descuento es del 12 si pongo .88 ya te da el resultado mas corto , y que imprimiera su descuento con su total, sucesivamente igual con los otros tipos, hasta al finl agregue la variable de visitantes en 1 para que cada que fuera pasando el ciclo mencionara visitante 1,2,3,etc. Costo total lo empece en 0 y la declare para sumar el costo de todos los visitantes en cada if de tipo agregue que el costo total era igual a el costo total que empezamos en 0 para guardar los valores que van sumando el costo que es el total ya con descuento.

# %%
visitantes = 1
costo_total = 0

while True:
    entrada = input(f"Visitante {visitantes}: ¿Cuál es tu edad? o escribe salir para terminar con tus visitantes")
    if entrada == ("salir"):
        break
    else:
        edad =float(entrada)
        visitantes = visitantes + 1
        if edad <= 3:
            print("Tu entrada es gratuita")
            costo = 0
        elif 3 < edad <= 17:
            costo = 30
            print("El costo es de 30")
        else:
            costo = 45
            print("El costo es de 45")

        visitante = input("Que tipo de visitante eres? adulto m, estudiante, profesor")

        if visitante == "adulto mayor":
            total = costo * .88
            costo_total = costo_total + total
            print("Tu descuento es del 12%, tu total es de", total)
        elif visitante == "estudiante" or visitante == "profesor":
            total = costo * .90
            costo_total = costo_total + total
            print("Tu descuento es del 10%, tu total es de", total)
        else:
            print("tu costo es general sin descuento")


print("fin del programa su total conjunto es de:",costo_total)
# Out:
# El costo es de 30
# Tu descuento es del 10%, tu total es de 27.0
# El costo es de 45
# Tu descuento es del 12%, tu total es de 39.6
# El costo es de 45
# Tu descuento es del 10%, tu total es de 40.5
# fin del programa su total conjunto es de: 107.1

# %% [markdown]
# # Extra 1
#
# Aqui era un problema similar al primero asi que declares mis variables principal de visitantes y los costos de los boletos por el tipo con el while empece mi ciclo pidiendo nuevamente la edad o escribiera salir para acabar si escribia salir con un if imprimia finalizado y rompia el programa sino la edad creamos la variable que sea el valor de visitante que fue donde se guardo la respuesta del usuario declare otra variable fuera del ciclo de visitantes sea = 1 para que al inicio vaya cambiando conforme a en que visitante va, saliendo cree otro if igual de las edades, cree la variable contador = en 1 para que tmb me diga en que boleto va, asi sucesivamente y imprimiera el costo es = el valor del boleto del tipo para que guardara los costos y sumar todo el total acumulaado hasta el final cree una variable del total acumulado que es = el total acumulado que la empezamos en 0 para guardar datos ern cada vuelta, y un ultimo if por si el total acumulado era mayor a 100 imprimir que supero el aforo y entregar el total acumulado.

# %%
boleto_mayores = 45
boleto_menores = 30
boleto_ninos = 0

total_acumulado = 0
visitantes = 1
contador = 1
while True:
    visitante = input(f"Hola visitante {visitantes} cual es tu edad? o escribe salir para acabar")
    if visitante ==("salir"):
        print("programa finalizado")
        break
    else:
        edad = float(visitante)
        visitantes = visitantes + 1
        if edad <= 3:
            print(f"Costo de boleto {contador} es {boleto_ninos}")
            contador = contador + 1
            costo = boleto_ninos
        elif 3 < edad <= 17:
            print(f"Costo de boleto {contador} es {boleto_menores}")
            contador = contador + 1
            costo = boleto_menores 
        else:
            print(f"Costo de boleto {contador} es {boleto_mayores}")
            contador = contador + 1
            costo = boleto_mayores

    total_acumulado = total_acumulado + costo

    if total_acumulado >=100:
        print("aforo alcanzado, se detiene el registro")
        print ("Total acumulado : $",total_acumulado)
        break
# Out:
# Costo de boleto 1 es 45
# Costo de boleto 2 es 45
# Costo de boleto 3 es 45
# aforo alcanzado, se detiene el registro
# Total acumulado : $ 135

# %% [markdown]
# # Extra 2
#
# cree una variable de visitantes para pedir la cantidad de personas otra de adultos que empezaba en 0 y de la suma de las edades estos son los contadores declare el for de indice en el rango de que empezara en el 1 la variable de la cantidad de visitantes y sumar 1 para que imprima tmb el ultimo visitante, entonces declare la variable edad para despues clasificarlos y sumar y promediar.
# Sumar edades para el contador que empezamos en 0ir sumando las edades en cada vuelta, y si la edad era mayor o igual a 18 guardarlo en la variable del contador de adultos luego declare el promedio que es igual a la suma de edades entre la cantidad de visitantes y que imprimiera los adultos y pusiera decimales y tmb el promedio de las edades con el prom que declare.

# %%
visitantes = int(input("Cuantos visitantes son?"))

adultos = 0
suma_edades = 0
for(i) in range(1, visitantes + 1):
    edad = int(input(f"cual es la edad del visitante {i}? "))

    suma_edades = suma_edades + edad

    if edad >= 18:
        adultos = adultos + 1

prom = suma_edades / visitantes
print("Adultos:",float(adultos))
print("El promedio de las edades es",float(prom))
# Out:
# Adultos: 2.0
# El promedio de las edades es 23.5

# %% [markdown]
# # Extra 3
#
# Este en la depuracion puse que imprimiera los 3 valores principales una vez viendo los datos ya se donde esta el error y se corrige la operacion.

# %%
precio = 45
descuento = 12
print(f"el precio es de {precio} y el descuento de {descuento}")
total = precio - descuento 
print(f"Total: ${total:.2f}")


precio = 45
descuento = .12
total = precio - (precio*descuento)
print(f"Total: ${total:.2f}")
# Out:
# el precio es de 45 y el descuento de 12
# Total: $33.00
# Total: $39.60

# %% [markdown]
# # Extra 4
#
# Este fue el que mas me costo tuve que investigar, declare la variable de la cantidad de en este caso el tamano de la torre, una vez dada la altura declaras for indice en el rango igual de 1 la variable donde se guarda los datos que dan y se le suma 1, declaramos otro for con n de constantes en el rango de indice para la cantidad de veces que se va a imprimir el indice y imprimimos el asterisco con end para no dar salto de linea y el ultimo print para el salto cuando haga la fila.

# %%
altura = int(input("Altura de la primide:"))
for i in range(1,altura + 1):
    for n in range(1,i + 1):
        print("*", end="")

    print()
