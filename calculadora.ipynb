# %%
username = input("Enter your username: ")
print("Hello,", username, "! Welcome to the program.")

ig = input("Cuanto tiempo le dedicas a instagram por dia? ")
tiktok= input("Cuanto tiempo le dedicas a tiktok por dia? ")
fb= input("Cuanto tiempo le dedicas a facebook por dia? ")
vg= input("Cuanto tiempo le dedicas a videojuegos por dia? ")
yt= input("Cuanto tiempo le dedicas a youtube por dia? ")

print("Listo ", username, ", ahora vamos a calcular cuanto tiempo le dedicas a las redes sociales y videojuegos por dia.")
print("el tiempo que le dedicas al uso de plataformas es ", int(ig) + int(tiktok) + int(fb) + int(vg) + int(yt), "horas por dia.")
# Out:
# Hello, 2 ! Welcome to the program.
# Listo  2 , ahora vamos a calcular cuanto tiempo le dedicas a las redes sociales y videojuegos por dia.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 11
#       7 vg= input("Cuanto tiempo le dedicas a videojuegos por dia? ")
#       8 yt= input("Cuanto tiempo le dedicas a youtube por dia? ")
#       9
#      10 print("Listo ", username, ", ahora vamos a calcular cuanto tiempo le dedicas a las redes sociales y videojuegos por dia.")
# ---> 11 print("el tiempo que le dedicas al uso de plataformas es ", float(ig) + float(tiktok) + float(fb) + float(vg) + float(yt), "horas por dia.")
#
# ValueError: could not convert string to float: ''
